# %% [markdown]
# # Fitting to the experimental .xye Time-Of-Flight data

# %% [markdown]
# In this notebook we will show how to load a xye file with experimental TOF profile and how to perform a parameter fit.

# %% [markdown]
# #### Import Python packages

# %%
import numpy as np

import easydiffraction as ed

# Vizualization
import py3Dmol
from bokeh.io import show, output_notebook
from bokeh.plotting import figure

# %%
output_notebook()
FIGURE_WIDTH = 990
FIGURE_HEIGHT = 300
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="da49b533-ed36-4a7e-8916-96d264cdd52c">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Sample

# %% [markdown]
# #### Show a CIF file content

# %%
cif_fname = 'diamond_phase.cif'

with open(cif_fname, 'r') as f:
    content = f.read()
    
print(content)
# Out:
# data_global
# _chemical_name_mineral 'Diamond'
# loop_
# _publ_author_name
# 'Wyckoff R W G'
# _journal_name_full 'Crystal Structures'
# _journal_volume 1
# _journal_year 1963
# _journal_page_first 7
# _journal_page_last 83
# _publ_section_title
# ;
#  Second edition. Interscience Publishers, New York, New York
# ;
# _database_code_amcsd 0011242
# _chemical_formula_sum 'C'
# _cell_length_a 3.56679
# _cell_length_b 3.56679
# _cell_length_c 3.56679
# _cell_angle_alpha 90
# _cell_angle_beta 90
# _cell_angle_gamma 90
# _cell_volume 45.377
# _exptl_crystal_density_diffrn      3.516
# _space_group_name_H-M_alt 'F d -3 m'
# loop_
# _space_group_symop_operation_xyz
#   'x,y,z'
#   'x,1/2+y,1/2+z'
#   '1/2+x,y,1/2+z'
#   '1/2+x,1/2+y,z'
#   '3/4+z,3/4-x,1/4+y'
#   '3/4+z,1/4-x,3/4+y'
#   '1/4+z,3/4-x,3/4+y'
#   '1/4+z,1/4-x,1/4+y'
#   '-y,1/2+z,1/2-x'
#   '-y,+z,-x'
#   '1/2-y,1/2+z,-x'
#   '1/2-y,+z,1/2-x'
#   '3/4+x,3/4-y,1/4+z'
#   '3/4+x,1/4-y,3/4+z'
#   '1/4+x,3/4-y,3/4+z'
#   '1/4+x,1/4-y,1/4+z'
#   '-z,1/2+x,1/2-y'
#   '-z,+x,-y'
#   '1/2-z,1/2+x,-y'
#   '1/2-z,+x,1/2-y'
#   '3/4+y,3/4-z,1/4+x'
#   '3/4+y,1/4-z,3/4+x'
#   '1/4+y,3/4-z,3/4+x'
#   '1/4+y,1/4-z,1/4+x'
#   '-x,1/2+y,1/2-z'
#   '-x,+y,-z'
#   '1/2-x,1/2+y,-z'
#   '1/2-x,+y,1/2-z'
#   '1/2+x,-z,1/2-y'
#   '1/2+x,1/2-z,-y'
#   '+x,-z,-y'
#   '+x,1/2-z,1/2-y'
#   '3/4-z,3/4+y,1/4+x'
#   '3/4-z,1/4+y,3/4+x'
#   '1/4-z,3/4+y,3/4+x'
#   '1/4-z,1/4+y,1/4+x'
#   '1/2+y,-x,1/2-z'
#   '1/2+y,1/2-x,-z'
#   '+y,-x,-z'
#   '+y,1/2-x,1/2-z'
#   '3/4-x,3/4+z,1/4+y'
#   '3/4-x,1/4+z,3/4+y'
#   '1/4-x,3/4+z,3/4+y'
#   '1/4-x,1/4+z,1/4+y'
#   '1/2+z,-y,1/2-x'
#   '1/2+z,1/2-y,-x'
#   '+z,-y,-x'
#   '+z,1/2-y,1/2-x'
#   '3/4-y,3/4+x,1/4+z'
#   '3/4-y,1/4+x,3/4+z'
#   '1/4-y,3/4+x,3/4+z'
#   '1/4-y,1/4+x,1/4+z'
#   'x,1/2+z,1/2+y'
#   'x,+z,+y'
#   '1/2+x,1/2+z,+y'
#   '1/2+x,+z,1/2+y'
#   '1/4-z,3/4-y,3/4-x'
#   '1/4-z,1/4-y,1/4-x'
#   '3/4-z,3/4-y,1/4-x'
#   '3/4-z,1/4-y,3/4-x'
#   'y,1/2+x,1/2+z'
#   'y,+x,+z'
#   '1/2+y,1/2+x,+z'
#   '1/2+y,+x,1/2+z'
#   '1/4-x,3/4-z,3/4-y'
#   '1/4-x,1/4-z,1/4-y'
#   '3/4-x,3/4-z,1/4-y'
#   '3/4-x,1/4-z,3/4-y'
#   'z,1/2+y,1/2+x'
#   'z,+y,+x'
#   '1/2+z,1/2+y,+x'
#   '1/2+z,+y,1/2+x'
#   '1/4-y,3/4-x,3/4-z'
#   '1/4-y,1/4-x,1/4-z'
#   '3/4-y,3/4-x,1/4-z'
#   '3/4-y,1/4-x,3/4-z'
#   '3/4+z,1/4+x,3/4-y'
#   '3/4+z,3/4+x,1/4-y'
#   '1/4+z,1/4+x,1/4-y'
#   '1/4+z,3/4+x,3/4-y'
#   '-y,1/2-z,1/2+x'
#   '-y,-z,+x'
#   '1/2-y,1/2-z,+x'
#   '1/2-y,-z,1/2+x'
#   '3/4+x,1/4+y,3/4-z'
#   '3/4+x,3/4+y,1/4-z'
#   '1/4+x,1/4+y,1/4-z'
#   '1/4+x,3/4+y,3/4-z'
#   '-z,1/2-x,1/2+y'
#   '-z,-x,+y'
#   '1/2-z,1/2-x,+y'
#   '1/2-z,-x,1/2+y'
#   '3/4+y,1/4+z,3/4-x'
#   '3/4+y,3/4+z,1/4-x'
#   '1/4+y,1/4+z,1/4-x'
#   '1/4+y,3/4+z,3/4-x'
#   '-x,1/2-y,1/2+z'
#   '-x,-y,+z'
#   '1/2-x,1/2-y,+z'
#   '1/2-x,-y,1/2+z'
#   '1/4-z,3/4+x,3/4+y'
#   '1/4-z,1/4+x,1/4+y'
#   '3/4-z,3/4+x,1/4+y'
#   '3/4-z,1/4+x,3/4+y'
#   'y,-z,-x'
#   'y,1/2-z,1/2-x'
#   '1/2+y,-z,1/2-x'
#   '1/2+y,1/2-z,-x'
#   '1/4-x,3/4+y,3/4+z'
#   '1/4-x,1/4+y,1/4+z'
#   '3/4-x,3/4+y,1/4+z'
#   '3/4-x,1/4+y,3/4+z'
#   'z,-x,-y'
#   'z,1/2-x,1/2-y'
#   '1/2+z,-x,1/2-y'
#   '1/2+z,1/2-x,-y'
#   '1/4-y,3/4+z,3/4+x'
#   '1/4-y,1/4+z,1/4+x'
#   '3/4-y,3/4+z,1/4+x'
#   '3/4-y,1/4+z,3/4+x'
#   'x,-y,-z'
#   'x,1/2-y,1/2-z'
#   '1/2+x,-y,1/2-z'
#   '1/2+x,1/2-y,-z'
#   '1/2-x,1/2+z,-y'
#   '1/2-x,+z,1/2-y'
#   '-x,1/2+z,1/2-y'
#   '-x,+z,-y'
#   '1/4+z,3/4-y,3/4+x'
#   '1/4+z,1/4-y,1/4+x'
#   '3/4+z,3/4-y,1/4+x'
#   '3/4+z,1/4-y,3/4+x'
#   '1/2-y,1/2+x,-z'
#   '1/2-y,+x,1/2-z'
#   '-y,1/2+x,1/2-z'
#   '-y,+x,-z'
#   '1/4+x,3/4-z,3/4+y'
#   '1/4+x,1/4-z,1/4+y'
#   '3/4+x,3/4-z,1/4+y'
#   '3/4+x,1/4-z,3/4+y'
#   '1/2-z,1/2+y,-x'
#   '1/2-z,+y,1/2-x'
#   '-z,1/2+y,1/2-x'
#   '-z,+y,-x'
#   '1/4+y,3/4-x,3/4+z'
#   '1/4+y,1/4-x,1/4+z'
#   '3/4+y,3/4-x,1/4+z'
#   '3/4+y,1/4-x,3/4+z'
#   '-x,-z,y'
#   '-x,1/2-z,1/2+y'
#   '1/2-x,-z,1/2+y'
#   '1/2-x,1/2-z,y'
#   '3/4+z,3/4+y,1/4-x'
#   '3/4+z,1/4+y,3/4-x'
#   '1/4+z,3/4+y,3/4-x'
#   '1/4+z,1/4+y,1/4-x'
#   '-y,-x,z'
#   '-y,1/2-x,1/2+z'
#   '1/2-y,-x,1/2+z'
#   '1/2-y,1/2-x,z'
#   '3/4+x,3/4+z,1/4-y'
#   '3/4+x,1/4+z,3/4-y'
#   '1/4+x,3/4+z,3/4-y'
#   '1/4+x,1/4+z,1/4-y'
#   '-z,-y,x'
#   '-z,1/2-y,1/2+x'
#   '1/2-z,-y,1/2+x'
#   '1/2-z,1/2-y,x'
#   '3/4+y,3/4+x,1/4-z'
#   '3/4+y,1/4+x,3/4-z'
#   '1/4+y,3/4+x,3/4-z'
#   '1/4+y,1/4+x,1/4-z'
#   '1/4-z,1/4-x,1/4-y'
#   '1/4-z,3/4-x,3/4-y'
#   '3/4-z,1/4-x,3/4-y'
#   '3/4-z,3/4-x,1/4-y'
#   'y,z,x'
#   'y,1/2+z,1/2+x'
#   '1/2+y,z,1/2+x'
#   '1/2+y,1/2+z,x'
#   '1/4-x,1/4-y,1/4-z'
#   '1/4-x,3/4-y,3/4-z'
#   '3/4-x,1/4-y,3/4-z'
#   '3/4-x,3/4-y,1/4-z'
#   'z,x,y'
#   'z,1/2+x,1/2+y'
#   '1/2+z,x,1/2+y'
#   '1/2+z,1/2+x,y'
#   '1/4-y,1/4-z,1/4-x'
#   '1/4-y,3/4-z,3/4-x'
#   '3/4-y,1/4-z,3/4-x'
#   '3/4-y,3/4-z,1/4-x'
#
# loop_
# _atom_site_label
# _atom_site_type_symbol
# _atom_site_symmetry_multiplicity
# _atom_site_Wyckoff_symbol
# _atom_site_fract_x
# _atom_site_fract_y
# _atom_site_fract_z
# _atom_site_B_iso_or_equiv
# _atom_site_occupancy
# _atom_site_attached_hydrogens
# C1 C 8 a 0 0 0 0. 1. 0

# %% [markdown]
# #### Create a new TOF job based on the CIF file

# %%
job = ed.Job(type='tof')
job.add_sample_from_file(cif_fname)
# Out:
# Several values of it_coordinate_system_code have been defined:
# 2, 1
# The default value has been choosen:'2'.
# Several values of it_coordinate_system_code have been defined:
# 2, 1
# The default value has been choosen:'2'.

# %% [markdown]
# Default job type is `pd-cwl-unp-1d-neut` for Powder, Constant Wavelength, Unpolarized, 1D, Neutrons
# To switch the job to TOF, we can set it in the constructor, or assing afterwards.
# The string could also be `type='pd-tof-unp-1d-neut'` or any susbset of these, like `type='tof-unp-neut'`

# %%
phases = job.phases
phase = phases[0]

print(phases)
print(phase)
# Out:
# Collection of 1 phases: ['global']
# Phase `global`

# %% [markdown]
# #### Visualise the structure

# %%
structure = py3Dmol.view()
structure.addModel(phase.cif, 'cif')
structure.setStyle({'sphere':{'colorscheme':'Jmol','scale':.2},'stick':{'colorscheme':'Jmol','radius': 0.1}})
structure.addUnitCell()
structure.replicateUnitCell(2,2,1)
structure.zoomTo()
# Out:
# <div id="3dmolviewer_172803961760976"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_172803961760976" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.1.0/3Dmol-min.js');
# }
#
# var viewer_172803961760976 = null;
# var warn = document.getElementById("3dmolwarning_172803961760976");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_172803961760976 = $3Dmol.createViewer(document.getElementById("3dmolviewer_172803961760976"),{backgroundColor:"white"});
# viewer_172803961760976.zoomTo();
# 	viewer_172803961760976.addModel("data_global\n_cell_length_a 3.56679\n_cell_length_b 3.56679\n_cell_length_c 3.56679\n_cell_angle_alpha 90.00000000\n_cell_angle_beta 90.00000000\n_cell_angle_gamma 90.00000000\n_space_group_name_H-M_ref 'F d -3 m'\n_space_group_IT_coordinate_system_code 1\n\nloop_\n_atom_site_label\n_atom_site_type_symbol\n_atom_site_fract_x\n_atom_site_fract_y\n_atom_site_fract_z\n_atom_site_occupancy\n_atom_site_adp_type\n_atom_site_B_iso_or_equiv\nC1 C 0.00000000 0.00000000 0.00000000 1.00000000 Biso 0.00000000","cif");
# 	viewer_172803961760976.setStyle({"sphere": {"colorscheme": "Jmol", "scale": 0.2}, "stick": {"colorscheme": "Jmol", "radius": 0.1}});
# 	viewer_172803961760976.addUnitCell();
# 	viewer_172803961760976.replicateUnitCell(2,2,1);
# 	viewer_172803961760976.zoomTo();
# viewer_172803961760976.render();
# });
# </script>

# %% [markdown]
# ## Experiment

# %% [markdown]
# #### Read in the data xye file

# %%
meas_fname = 'diamond_exp.xye'
job.add_experiment_from_file(meas_fname)

# %% [markdown]
# #### Extract the measured data

# %%
meas_x = job.experiment.x
meas_y = job.experiment.y

# %% [markdown]
# #### Visualize the measured data

# %%
fig = figure(width=FIGURE_WIDTH, height=FIGURE_HEIGHT)
fig.line(meas_x, meas_y, legend_label='Imeas', color='steelblue', line_width=2)
show(fig)
# Out:
#   <div id="efcb585a-ecc3-4f04-a5c9-dbad662cb0de" data-root-id="p1445" style="display: contents;"></div>

# %% [markdown]
# ## Analysis

# %% [markdown]
# #### The default job is of 1D powder neutron diffraction with time-of-flight type.

# %%
print(f"Job type: {job.type}")
# Out:
# Job type: Job type: pd-tof-unp-1d-neut

# %%
print(f"Current calculator engine: {job.calculator}")
# Out:
# Current calculator engine: CrysPy

# %% [markdown]
# #### Generate the calculated data
#
# Note that we do not need to pass the `x` values, since they are already known.

# %%
calc_y_cryspy = job.calculate_profile()

# %% [markdown]
# #### Visualize both the measured and calculated data

# %%
fig = figure(width=FIGURE_WIDTH, height=FIGURE_HEIGHT)
fig.line(meas_x, meas_y, legend_label='Imeas', color='steelblue', line_width=2)
fig.line(meas_x, calc_y_cryspy, legend_label='Icalc (CrysPy)', color='orangered', line_width=2)
show(fig)
# Out:
#   <div id="f688fb28-b901-4207-bb1e-8b00170e5fce" data-root-id="p1490" style="display: contents;"></div>

# %% [markdown]
# #### Set zero shift manually

# %%
job.sample.parameters.zero = -18.7

# %% [markdown]
# #### Set background points manually

# %%
p1 = (meas_x[0], 126)
p2 = (meas_x[-1], 15)
points = [p1, p2]

job.set_background(points)

# %%
calc_y_cryspy = job.calculate_profile(meas_x)

fig = figure(width=FIGURE_WIDTH, height=FIGURE_HEIGHT)
fig.line(meas_x, meas_y, legend_label='Imeas', color='steelblue', line_width=2)
fig.line(meas_x, calc_y_cryspy, legend_label='Icalc (CrysPy)', color='orangered', line_width=2)
show(fig)
# Out:
#   <div id="aedfb737-c75b-4e5d-a20d-ad57bb20a412" data-root-id="p1547" style="display: contents;"></div>

# %% [markdown]
# #### Redefine default parameters to get closer to the experimental profile

# %%
job.phases[0].scale = 10.0
job.parameters.zero_shift = -18.76
job.parameters.dtt1 = 22602
job.parameters.dtt2 = -8.3
job.parameters.alpha0 = 0.13
job.parameters.beta0 = 0.083
job.parameters.sigma1 = 1.0
job.parameters.ttheta_bank = 90.0

# %% [markdown]
# #### Define parameters to optimize

# %%
job.phases[0].scale = 10.0
job.phases[0].cell.length_a.fixed = False
job.phases[0].cell.length_b.fixed = False
job.phases[0].cell.length_c.fixed = False
job.pattern.zero_shift.fixed = False
job.parameters.dtt1.fixed = False
job.parameters.dtt2.fixed = False
job.parameters.alpha0.fixed = True
job.parameters.beta0.fixed = True

# %%
calc_y_cryspy = job.calculate_profile(meas_x)

fig = figure(width=FIGURE_WIDTH, height=FIGURE_HEIGHT)
fig.line(meas_x, meas_y, legend_label='Imeas', color='steelblue', line_width=2)
fig.line(meas_x, calc_y_cryspy, legend_label='Icalc (CrysPy)', color='orangered', line_width=2)
show(fig)
# Out:
#   <div id="ecbfee3f-60ec-44fa-bea0-34d17503a2d8" data-root-id="p1604" style="display: contents;"></div>

# %% [markdown]
# #### Perform the fit with Bumps Simplex method

# %%
print(f"Available minimizers: {job.analysis.available_minimizers}")
print(f"Current minimizer: {job.analysis.current_minimizer}")
job.analysis.current_minimizer = 'Bumps_simplex'
print(f"Current minimizer: {job.analysis.current_minimizer}")
# Out:
# Available minimizers: ['LMFit', 'LMFit_leastsq', 'LMFit_powell', 'LMFit_cobyla', 'LMFit_differential_evolution', 'LMFit_scipy_least_squares', 'Bumps', 'Bumps_simplex', 'Bumps_newton', 'Bumps_lm', 'DFO', 'DFO_leastsq']
# Current minimizer: LMFit_leastsq
# Current minimizer: Bumps_simplex

# %%
# %%time
job.fit()

# %% [markdown]
# Please be aware that this is a long fit, it can take about 15-20 min.

# %%
print("The fit has been successful: {}".format(job.fitting_results.success))
if job.fitting_results.success:    
    print("The gooodness of fit (chi2) is: {}".format(job.fitting_results.reduced_chi))
    print(job.phases[0].scale)
    print(job.pattern.zero_shift)
    print(job.parameters.dtt1)
    print(job.parameters.dtt2)

# %%
calc_y_cryspy = job.calculate_profile(meas_x)

fig = figure(width=FIGURE_WIDTH, height=FIGURE_HEIGHT)
fig.line(meas_x, meas_y, legend_label='Imeas', color='steelblue', line_width=2)
fig.line(meas_x, calc_y_cryspy, legend_label='Icalc (CrysPy)', color='orangered', line_width=2)
fig.line(meas_x, meas_y-calc_y_cryspy, legend_label='Imeas - Icalc (CrysPy)', color='olivedrab', line_width=2)
show(fig)
